# %%
from lib.prismaClient import prisma
import sys, os
import asyncio
import logging
import json
from pprintpp import pprint
from langchain_ollama.llms import OllamaLLM
import re
from enum import Enum
from pydantic import BaseModel
from typing import List, Optional

# %%
class OCRElementEnumType(str, Enum):
    number = "number"
    biologyTest = "biologyTest"
    otherText = "otherText"


class OCRrawResponse(BaseModel):
    image_size: List[float]
    coordinates: List[tuple[str, List[float]]]
    text: List[str]


class OCResponse(BaseModel):
    id: str
    text: str
    x: float
    y: float
    width: float
    high: float
    typeOfContent: Optional[OCRElementEnumType] = None
    systemMapping: Optional[str] = None
    notFoundInSystemMapping: bool = False
    associatedNumberValueId: str | None = None
    associatedNumberValue: str | None = None

# %%
doc_id = "c5f0fcd6-0562-4c69-b992-835e9f84e074"

# %%
document: List[OCResponse] = []
try:
    await prisma.connect()
    rawDocument = await prisma.patientscanneddocument.find_first_or_raise(
        where={"id": doc_id}
    )
    if rawDocument.extractedData == None:
        raise Exception("No extracted data")
    pattern = r"^[><=]?\s*-?\d+(\.\d+)?$"
    # Parse the JSON data as list of dictionaries
    document_data = OCRrawResponse.model_validate(json.loads(rawDocument.extractedData))
    document = list(
        map(
            lambda x: OCResponse(
                id=x[0],
                text=re.sub(r":", "", re.sub(r"Text Box ID \d+: ?", "", x[0])),
                x=x[1][0],
                y=x[1][1],
                width=x[1][2],
                high=x[1][3],
                typeOfContent=(
                    OCRElementEnumType.number
                    if re.match(pattern, re.sub(r"Text Box ID \d+: ?", "", x[0]))
                    else None
                ),
            ),
            filter(lambda c: c[0].startswith("Text Box ID"), document_data.coordinates),
        )
    )

    await prisma.disconnect()
    pass
except Exception as e:
    await prisma.disconnect()
    logging.error(e)
    raise e

pprint(document)
# Out:
# [
#     OCResponse(id='Text Box ID 0: B', text='B', x=1090.0, y=0.0, width=40.0, high=24.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 1: lonogramme: Kaliemie (k)', text='lonogramme Kaliemie (k)', x=158.0, y=72.99999237060547, width=445.0, high=48.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 2: 3.76', text='3.76', x=976.9999389648438, y=69.0, width=75.00006103515625, high=47.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 3: Ionogramme: Natremie (Na)', text='Ionogramme Natremie (Na)', x=155.99996948242188, y=123.0, width=487.0000305175781, high=50.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 4: 139.4', text='139.4', x=979.0, y=121.0, width=95.0, high=45.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 5: Bilan renal', text='Bilan renal', x=156.0, y=237.0, width=220.0, high=49.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 6: Uree sanguine', text='Uree sanguine', x=159.00001525878906, y=281.0, width=248.99998474121094, high=55.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 7: 0.32', text='0.32', x=984.0, y=279.0, width=75.0, high=45.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 8: Creatine sanguine', text='Creatine sanguine', x=160.99998474121094, y=336.0, width=312.0, high=47.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 9: 7.3', text='7.3', x=984.0, y=334.0, width=64.0, high=42.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 10: H', text='H', x=1102.0, y=488.0, width=32.0, high=47.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 11: 21.3', text='21.3', x=987.0, y=577.9999389648438, width=83.0, high=41.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 12: TP (inr) taux de prothrombine', text='TP (inr) taux de prothrombine', x=158.00003051757812, y=590.0000610351562, width=521.0, high=37.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 13: 34.3', text='34.3', x=993.0, y=627.0, width=78.0, high=45.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 14: TQ (inr) temps de quick', text='TQ (inr) temps de quick', x=155.99996948242188, y=642.0, width=417.0000305175781, high=42.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 15: 5.18', text='5.18', x=993.0, y=677.0, width=81.0, high=47.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 16: INR (Interational Normalizated Ratio)', text='INR (Interational Normalizated Ratio)', x=158.0, y=696.0, width=644.0, high=30.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 17: 0.81', text='0.81', x=998.0, y=932.0, width=80.0, high=48.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 18: TSH 3eme generation', text='TSH 3eme generation', x=146.0, y=957.0, width=382.0, high=39.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 19: FORMULE', text='FORMULE', x=848.0, y=1058.0, width=271.0, high=51.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 20: 4.36', text='4.36', x=687.9999389648438, y=1126.9998779296875, width=80.0, high=45.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 21: Globules Rouges', text='Globules Rouges', x=146.0, y=1141.0, width=297.0, high=42.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 22: 12.4', text='12.4', x=686.0, y=1180.9998779296875, width=82.0, high=45.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 23: Hemoglobine', text='Hemoglobine', x=144.0, y=1198.0, width=239.0, high=44.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 24: 37.8', text='37.8', x=680.0, y=1236.0, width=89.0, high=41.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 25: Hematocrite', text='Hematocrite', x=141.0, y=1251.9998779296875, width=228.0, high=45.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 26: 86.8', text='86.8', x=686.0, y=1292.0, width=82.0, high=48.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 27: VGM', text='VGM', x=144.0, y=1310.9998779296875, width=109.0, high=45.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 28: 32.7', text='32.7', x=686.0, y=1351.0, width=82.0, high=48.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 29: CCMH', text='CCMH', x=136.99998474121094, y=1366.0, width=142.00001525878906, high=49.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 30: 28.4', text='28.4', x=686.0, y=1408.0, width=80.0, high=48.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 31: TGMH', text='TGMH', x=134.0, y=1425.0001220703125, width=146.0, high=44.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 32: 4.1', text='4.1', x=686.0000610351562, y=1467.0, width=61.0, high=48.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 33: Globules Blancs', text='Globules Blancs', x=136.99998474121094, y=1484.0, width=287.0, high=42.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 34: 2.6', text='2.6', x=683.0000610351562, y=1526.0, width=67.0, high=48.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 35: PN_neutrophiles', text='PN_neutrophiles', x=134.0, y=1543.0, width=302.0, high=42.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 36: 64.0', text='64.0', x=686.0, y=1586.0, width=82.0, high=47.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 37: PNN', text='PNN', x=127.0, y=1601.0, width=106.0, high=48.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 38: 0.08', text='0.08', x=686.0, y=1645.0, width=80.0, high=47.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 39: PN_Eosinophiles', text='PN_Eosinophiles', x=130.0, y=1662.0, width=303.0, high=42.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 40: 02', text='02', x=683.0000610351562, y=1704.0, width=55.0, high=52.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 41: PNE', text='PNE', x=128.0, y=1718.0001220703125, width=97.0, high=52.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 42: 00', text='00', x=686.0000610351562, y=1768.0001220703125, width=49.0, high=45.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 43: PN_Basophiles', text='PN_Basophiles', x=125.00001525878906, y=1783.0, width=275.0, high=41.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 44: 00', text='00', x=683.0, y=1825.0, width=57.0, high=49.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 45: PNB', text='PNB', x=125.00001525878906, y=1839.0, width=97.0, high=52.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 46: 26.2', text='26.2', x=686.0, y=1886.0, width=82.0, high=48.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 47: LYM', text='LYM', x=123.0, y=1900.0, width=111.0, high=52.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 48: 1.1', text='1.1', x=683.0000610351562, y=1945.0, width=67.0, high=50.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 49: Lymphocytes', text='Lymphocytes', x=118.0, y=1963.0, width=254.0, high=50.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 50: 0.4', text='0.4', x=683.0000610351562, y=2009.0, width=67.0, high=48.0, typeOfContent=<OCRElementEnumType.number: 'number'>, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 51: Monocytes', text='Monocytes', x=113.00001525878906, y=2024.0, width=210.99998474121094, high=51.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 52: ABORATOIREDAMALYSESVE', text='ABORATOIREDAMALYSESVE', x=642.0, y=2076.0, width=484.0, high=34.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 53: MONO', text='MONO', x=113.00001525878906, y=2090.0, width=149.99998474121094, high=47.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 54: 219BDELVALEKCH', text='219BDELVALEKCH', x=654.0, y=2131.0, width=480.0, high=41.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 55: Plaquettes', text='Plaquettes', x=111.00001525878906, y=2154.0, width=201.99998474121094, high=54.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
#     OCResponse(id='Text Box ID 56: FOamaclah Sieiogi', text='FOamaclah Sieiogi', x=687.0, y=2186.0, width=447.0, high=37.0, typeOfContent=None, systemMapping=None, notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None),
# ]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
documentContent = list(
    map(
        lambda x: x.text,
        filter(lambda y: y.typeOfContent != OCRElementEnumType.number, document),
    )
)
print(documentContent)
# Out:
# ['B', 'lonogramme Kaliemie (k)', 'Ionogramme Natremie (Na)', 'Bilan renal', 'Uree sanguine', 'Creatine sanguine', 'H', 'TP (inr) taux de prothrombine', 'TQ (inr) temps de quick', 'INR (Interational Normalizated Ratio)', 'TSH 3eme generation', 'FORMULE', 'Globules Rouges', 'Hemoglobine', 'Hematocrite', 'VGM', 'CCMH', 'TGMH', 'Globules Blancs', 'PN_neutrophiles', 'PNN', 'PN_Eosinophiles', 'PNE', 'PN_Basophiles', 'PNB', 'LYM', 'Lymphocytes', 'Monocytes', 'ABORATOIREDAMALYSESVE', 'MONO', '219BDELVALEKCH', 'Plaquettes', 'FOamaclah Sieiogi']

# %%
from pydantic import Field, BaseModel
from typing import List
from langchain_core.output_parsers import PydanticOutputParser


class FilteredData(BaseModel):
    biologicalTests: List[str] = Field(
        description="List of the filtered biological tests"
    )


parser = PydanticOutputParser(pydantic_object=FilteredData)

# %%
from langchain_ollama.chat_models import ChatOllama
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.prompts.chat import ChatPromptTemplate, HumanMessagePromptTemplate


model = ChatOllama(
    model="gemma2:latest",
    base_url="100.108.14.46",
    keep_alive="10m",
    temperature=0.2,
)

system_prompt = """
you are a helpful agent specialized in analyzing content of biological test OCR. the user will give you an array of strings from an OCR of biological test results written in French. analyze this array keep only the elements referring to a biological test and return another array formed with the filtered elements.
"""


user_prompt = HumanMessagePromptTemplate.from_template(
    "{request}\n{format_instructions}"
)
chat_prompt = ChatPromptTemplate.from_messages(
    [
        SystemMessage(content=system_prompt),
        user_prompt,
    ]
)
request = chat_prompt.format_prompt(
    request=str(documentContent), format_instructions=parser.get_format_instructions()
).to_messages()

results = model.invoke(request, temperature=0, format='json')
results_values: FilteredData | None = None
if results:
    results_values = parser.parse(results.content)  # type: ignore
results_values.biologicalTests # type: ignore
# Out:
# ['lonogramme Kaliemie (k)',
#  'Ionogramme Natremie (Na)',
#  'Bilan renal',
#  'Uree sanguine',
#  'Creatine sanguine',
#  'TP (inr) taux de prothrombine',
#  'TQ (inr) temps de quick',
#  'INR (Interational Normalizated Ratio)',
#  'TSH 3eme generation',
#  'FORMULE',
#  'Globules Rouges',
#  'Hemoglobine',
#  'Hematocrite',
#  'VGM',
#  'CCMH',
#  'TGMH',
#  'Globules Blancs',
#  'PN_neutrophiles',
#  'PNN',
#  'PN_Eosinophiles',
#  'PNE',
#  'PN_Basophiles',
#  'PNB',
#  'LYM',
#  'Lymphocytes',
#  'Monocytes',
#  'Plaquettes']

# %%
for index, doc in enumerate(document):
    if results_values:
        if doc.text in results_values.biologicalTests:
            document[index].typeOfContent = OCRElementEnumType.biologyTest

# document

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from tqdm import tqdm

# Specify the model name and local directory for saving

local_model_path = "./huggingFaceModels/paraphrase-multilingual-MiniLM-L12-v2"

# model_name = "mixedbread-ai/mxbai-embed-large-v1"
# model_name='microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract'
model_name = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
model_kwargs = {"device": "cuda"}
encode_kwargs = {"normalize_embeddings": False}
hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
    cache_folder=local_model_path,
)

# %%
from qdrant_client import QdrantClient

url = "100.108.14.46"
client = QdrantClient(url)
collection_exists = client.collection_exists(
    collection_name="biologyParametersStore",
)

# %%
for key, doc in enumerate(document):
    if doc.typeOfContent == OCRElementEnumType.biologyTest:

        query_vector = await hf.aembed_query(doc.text)

        results = client.search(
            collection_name="biologyParametersStore",
            query_vector=query_vector,
            limit=1,
            score_threshold=0.7,
        )
        formatted_results = [
            {
                "id": result.id,
                "score": result.score,
                "payload": result.payload,
            }
            for result in results
        ]
        if len(formatted_results) > 0:
            document[key].systemMapping = formatted_results[0]["payload"][
                "parameterName"
            ]
            pprint(document[key])
# Out:
# OCResponse(id='Text Box ID 1: lonogramme: Kaliemie (k)', text='lonogramme Kaliemie (k)', x=158.0, y=72.99999237060547, width=445.0, high=48.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Potassium (K)', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 3: Ionogramme: Natremie (Na)', text='Ionogramme Natremie (Na)', x=155.99996948242188, y=123.0, width=487.0000305175781, high=50.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Sodium (Na)', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 6: Uree sanguine', text='Uree sanguine', x=159.00001525878906, y=281.0, width=248.99998474121094, high=55.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Blood Urea Nitrogen (BUN)', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 8: Creatine sanguine', text='Creatine sanguine', x=160.99998474121094, y=336.0, width=312.0, high=47.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Total Cholesterol', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 12: TP (inr) taux de prothrombine', text='TP (inr) taux de prothrombine', x=158.00003051757812, y=590.0000610351562, width=521.0, high=37.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Prothrombin Time (PT)', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 19: FORMULE', text='FORMULE', x=848.0, y=1058.0, width=271.0, high=51.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='ESR value', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 21: Globules Rouges', text='Globules Rouges', x=146.0, y=1141.0, width=297.0, high=42.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Red Blood Cell (RBC) count', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 23: Hemoglobine', text='Hemoglobine', x=144.0, y=1198.0, width=239.0, high=44.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Hemoglobin (Hb)', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 27: VGM', text='VGM', x=144.0, y=1310.9998779296875, width=109.0, high=45.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Very Low-Density Lipoprotein (VLDL)', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 29: CCMH', text='CCMH', x=136.99998474121094, y=1366.0, width=142.00001525878906, high=49.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Mean Corpuscular Hemoglobin Concentration (MCHC)', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 31: TGMH', text='TGMH', x=134.0, y=1425.0001220703125, width=146.0, high=44.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Triglycerides', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 37: PNN', text='PNN', x=127.0, y=1601.0, width=106.0, high=48.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Neutrophils', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 39: PN_Eosinophiles', text='PN_Eosinophiles', x=130.0, y=1662.0, width=303.0, high=42.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Eosinophils', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 41: PNE', text='PNE', x=128.0, y=1718.0001220703125, width=97.0, high=52.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Neutrophils', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 45: PNB', text='PNB', x=125.00001525878906, y=1839.0, width=97.0, high=52.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Neutrophils', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 47: LYM', text='LYM', x=123.0, y=1900.0, width=111.0, high=52.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='ESR value', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 49: Lymphocytes', text='Lymphocytes', x=118.0, y=1963.0, width=254.0, high=50.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Lymphocytes #', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 51: Monocytes', text='Monocytes', x=113.00001525878906, y=2024.0, width=210.99998474121094, high=51.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Monocytes', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)
# OCResponse(id='Text Box ID 55: Plaquettes', text='Plaquettes', x=111.00001525878906, y=2154.0, width=201.99998474121094, high=54.0, typeOfContent=<OCRElementEnumType.biologyTest: 'biologyTest'>, systemMapping='Platelet count', notFoundInSystemMapping=False, associatedNumberValueId=None, associatedNumberValue=None)

# %%
numericValues: List[OCResponse] = list(
    filter(lambda x: x.typeOfContent == OCRElementEnumType.number, document)
)

for doc in document:
    if doc.typeOfContent == OCRElementEnumType.biologyTest:
        y_threshold = doc.high / 2
        relatedNumericalValues = list(sorted(
            list(
                filter(
                    lambda filter: abs((doc.y + doc.high) - (filter.y + filter.high))
                    <= y_threshold,
                    numericValues,
                )
            ),
            key=lambda sort: sort.x,
            reverse=False,
        ))
        
        if len(relatedNumericalValues) > 0 : 
            relatedNumericalValue = relatedNumericalValues[0]
            doc.associatedNumberValue = relatedNumericalValue.text
            doc.associatedNumberValueId= relatedNumericalValue.id
            
            print( doc.text, doc.associatedNumberValue)
# Out:
# lonogramme Kaliemie (k) 3.76
# Ionogramme Natremie (Na) 139.4
# Uree sanguine 0.32
# Creatine sanguine 7.3
# TP (inr) taux de prothrombine 21.3
# TQ (inr) temps de quick 34.3
# INR (Interational Normalizated Ratio) 5.18
# TSH 3eme generation 0.81
# Globules Rouges 4.36
# Hemoglobine 12.4
# Hematocrite 37.8
# VGM 86.8
# CCMH 32.7
# TGMH 28.4
# Globules Blancs 4.1
# PN_neutrophiles 2.6
# PNN 64.0
# PN_Eosinophiles 0.08
# PNE 02
# PN_Basophiles 00
# PNB 00
# LYM 26.2
# Lymphocytes 1.1
# Monocytes 0.4
